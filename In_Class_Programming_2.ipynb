# %%
from ast import arguments
# @title
import statistics
from statistics import mean
import random
print("Question 1: ")
ages = [19, 22, 19, 24, 20, 25, 26, 24, 25, 24]

ages.sort() #sort the list
print(ages)

minAge = min(ages)
maxAge = max(ages)
ages.insert(0, minAge) #insert the minimum age again
ages.insert(-1, maxAge) #insert maximum age again
print(ages)

medianValue = statistics.median(ages) #find the median using statistics built in class
print(f"The median is {medianValue}")

averageSum = mean(ages) #find and print the mean using mean function

print(f"The average sum is {averageSum}")

rangeAge = maxAge - minAge
print(f"Range of the ages is {rangeAge}") #obtain and print the range

print("\nQuestion 2: ")
dog = {} #create the dog dictionary
dog["name"] = "Kirin"
dog["color"] = "Brown"
dog["breed"] = "Golden Retreiver"
dog["legs"] = "Short"
dog["age"] = "3 years"
print(f"dog dictionary = {dog}") #display dog dictionary

studentDict = {"first_name" : "Captain", "last_name" : "Kurk", "gender" : "Male", "age" : 25,
 "marital status" : "Single", "skills" : [], "country" : "US", "city" : "Hawaii", "address" : "CAPTAIN COOK HI 96704-0461"} #create student dictionary
print(f"Length of the student dictionary is {len(studentDict)}") #print the length
print(studentDict["skills"]) #obtain the value of the skills key
studentDict["skills"] += ["Programming", "Playing the Guitar"] #add values to skills key
keysList = list(studentDict.keys())
print(keysList) #convert keys of student dictionary to list, display
valuesList = list(studentDict.values())
print(valuesList) #convert values of student dictionary to list, display


print()
print("Question 3: ")
it_companies = {'Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon'}
A = {19, 22, 24, 20, 25, 26}
B = {19, 22, 20, 25, 26, 24, 28, 27}
age = [22, 19, 24, 25, 26, 24, 25, 24]

print(f"Length of IT companies set is {len(it_companies)}") #display length of companies set
it_companies.add('Twitter') #add values
print(it_companies)
it_companies.update({'Intel'}, {'Dell'}, {'Verizon'}, {'Paypal'}) #add random values
print(it_companies)
it_companies.remove('Intel') #remove a value in the set
print(it_companies)
it_companies.discard('Dell')
it_companies.remove('Paypal')
print(it_companies)

#The discard() method removes a specified item from the set
#the main difference is that the remove() method will raise an error
# if the specified item does not exist in the set, and the discard() method will not.
AunionB = A.union(B)
print(f"The Union of the sets is: {AunionB}")  #printing the joined set using the union function
def intersection(lst1, lst2): #intersection function to find the common values in both sets
    return list(set(lst1) & set(lst2))
print(f"The intersection of the sets is: {intersection(A, B)}") #printing the intersection set
print(f"Is set A a subset of set B? {A.issubset(B)}") #find if A is a subset of B using issubset function
print(f"Are set A and set B disjoint sets? {A.isdisjoint(B)}") #find if A and B are disjoint sets with isdisjoint function
print(A.union(B))
print(B.union(A))
print(f"The symmetric difference of the sets is: {A.symmetric_difference(B)}") #find the symmetric difference of the sets
#Completely delete the sets
del A
del B
#Compare the length of the ages set with the ages list, print appropriate results
if len(ages) > len(set(ages)):
  print("The ages list is bigger than the ages set")
elif len(set(ages)) > len(ages):
  print("The ages set is bigger than the ages list")
else:
  print("The set and list are the same length")


print("\nQuestion 4: ")
class Employee:
    empCount = 0 #Number of Employees counter
    def __init__(self, name = "Jackson", department = "Basement", family = 6, salary = 20000):
        self.name = name
        self.family = family
        self.salary = salary
        self.department = department
        Employee.empCount += 1

    def person_info(self):
        return f'{self.name} works in the {self.department}. They live with a family of {self.family} and make a total of ${self.salary} per year.'

    def avg_Salary(self, totalSalary): #function to average salary vallues
        return f"\nThe average salary in the normal office is ${mean(totalSalary)}"

class FullTimeEmployee(Employee):
  def person_info(self):
        return f'{self.name} works in the {self.department} Full Time. They live with a family of {self.family} and make a total of ${self.salary} per year.'
  def avg_Salary(self, totalSalary): #function to average salary for full time employees
        return f"\nThe average salary in the office for Full Time Employees is ${mean(totalSalary)}"


#Creating different Employee and FullTimeEmployee objects
Emp1 = Employee()
print(Emp1.person_info())
Emp2 = Employee('John Doe', 'Human Resources Departmnet', 5, 500000)
print(Emp2.person_info())
Emp3 = Employee('Sarah', 'Accounting Department', 2, 300000)
print(Emp3.person_info())
Emp4 = Employee('Bella', 'Data Analysis Department', 4, 600000)
print(Emp4.person_info())

Fulltime1 = FullTimeEmployee('Kirito', 'Food Department', 2, 200000)
Fulltime2 = FullTimeEmployee('Marisa', 'Programming Department', 3, 800000)
print(Fulltime1.person_info())
print(Fulltime2.person_info())

#add each one to the respective salary list, print out the average using the average functions created in the class
totalSalary = []
totalSalary.append(Emp1.salary)
totalSalary.append(Emp2.salary)
totalSalary.append(Emp3.salary)
totalSalary.append(Emp4.salary)

totalSalary2 = []
totalSalary2.append(Fulltime1.salary)
totalSalary2.append(Fulltime2.salary)

print(FullTimeEmployee().avg_Salary(totalSalary2))
print(Employee().avg_Salary(totalSalary))
# Out:
# Question 1:
# [19, 19, 20, 22, 24, 24, 24, 25, 25, 26]
# [19, 19, 19, 20, 22, 24, 24, 24, 25, 25, 26, 26]
# The median is 24.0
# The average sum is 22.75
# Range of the ages is 7
#
# Question 2:
# dog dictionary = {'name': 'Kirin', 'color': 'Brown', 'breed': 'Golden Retreiver', 'legs': 'Short', 'age': '3 years'}
# Length of the student dictionary is 9
# []
# ['first_name', 'last_name', 'gender', 'age', 'marital status', 'skills', 'country', 'city', 'address']
# ['Captain', 'Kurk', 'Male', 25, 'Single', ['Programming', 'Playing the Guitar'], 'US', 'Hawaii', 'CAPTAIN COOK HI 96704-0461']
#
# Question 3:
# Length of IT companies set is 7
# {'Facebook', 'Twitter', 'Google', 'Oracle', 'IBM', 'Microsoft', 'Amazon', 'Apple'}
# {'Twitter', 'IBM', 'Intel', 'Microsoft', 'Amazon', 'Dell', 'Facebook', 'Verizon', 'Google', 'Oracle', 'Paypal', 'Apple'}
# {'Twitter', 'IBM', 'Microsoft', 'Amazon', 'Dell', 'Facebook', 'Verizon', 'Google', 'Oracle', 'Paypal', 'Apple'}
# ...
